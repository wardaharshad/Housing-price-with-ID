# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %% [markdown]
# # Dataset

# %%
dataset= pd.read_csv("housing price.csv")
dataset
# Out:
#         Id      SalePrice
# 0     1461  169277.052498
# 1     1462  187758.393989
# 2     1463  183583.683570
# 3     1464  179317.477511
# 4     1465  150730.079977
# ...    ...            ...
# 1454  2915  167081.220949
# 1455  2916  164788.778231
# 1456  2917  219222.423400
# 1457  2918  184924.279659
# 1458  2919  187741.866657
#
# [1459 rows x 2 columns]

# %% [markdown]
# # Data preprocessing

# %%
x = dataset.iloc[:,:-1].values
y = dataset.iloc[:,1:2].values

# %%
x
# Out:
# array([[1461],
#        [1462],
#        [1463],
#        ...,
#        [2917],
#        [2918],
#        [2919]], dtype=int64)

# %%
y
# Out:
# array([[169277.0524984 ],
#        [187758.39398877],
#        [183583.68356955],
#        ...,
#        [219222.42340006],
#        [184924.279659  ],
#        [187741.86665748]])

# %% [markdown]
# # Splitting

# %%
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size=1/3, random_state=0)

# %% [markdown]
# # Fitting

# %%
from sklearn.linear_model import LinearRegression
regressor= LinearRegression()
regressor.fit(x_train,y_train)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Prediction

# %%
y_pred= regressor.predict(x_test)

# %% [markdown]
# # Plotting Train set

# %%
plt.scatter(x_train, y_train, color= "red")
plt.plot(x_train, regressor.predict(x_train), color= "green")
plt.title("Housing Price by ID (Trainning set)")
plt.xlabel("ID")
plt.ylabel("sale price")
plt.show()

# %% [markdown]
# # Plotting Test Set

# %%
plt.scatter(x_test, y_test, color= "red")
plt.plot(x_train, regressor.predict(x_train), color= "green")
plt.title("Housing Price by ID (Trainning set)")
plt.xlabel("ID")
plt.ylabel("sale price")
plt.show()

# %% [markdown]
# # Line doesnot best fit

# %% [markdown]
# # Apply polynomial regression

# %% [markdown]
# # Fitting

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 3)
x_poly = poly_reg.fit_transform(x)
poly_reg.fit(x_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Plotting Train set

# %%
plt.scatter(x, y, color = 'yellow')
plt.plot(x, lin_reg_2.predict(poly_reg.fit_transform(x)), color = 'red')
plt.title("Housing Price by ID (Trainning set)")
plt.xlabel("ID")
plt.ylabel("sale price")
plt.show()

# %% [markdown]
# # Plotting Test set

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, lin_reg_2.predict(poly_reg.fit_transform(x)), color = 'blue')
plt.title("Housing Price by ID (Trainning set)")
plt.xlabel("ID")
plt.ylabel("sale price")
plt.show()

# %%
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape((len(x_grid), 1))
plt.scatter(x, y, color = 'red')
plt.plot(x_grid, lin_reg_2.predict(poly_reg.fit_transform(x_grid)), color = 'blue')
plt.title("Housing Price by ID (Trainning set)")
plt.xlabel("ID")
plt.ylabel("sale price")
plt.show()

# %% [markdown]
# # changing degree

# %%
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 5)
x_poly = poly_reg.fit_transform(x)
poly_reg.fit(x_poly, y)
lin_reg_2 = LinearRegression()
lin_reg_2.fit(x_poly, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %% [markdown]
# # Again plotting

# %%
plt.scatter(x, y, color = 'yellow')
plt.plot(x, lin_reg_2.predict(poly_reg.fit_transform(x)), color = 'red')
plt.title("Housing Price by ID (Trainning set)")
plt.xlabel("ID")
plt.ylabel("sale price")
plt.show()

# %%
plt.scatter(x, y, color = 'red')
plt.plot(x, lin_reg_2.predict(poly_reg.fit_transform(x)), color = 'blue')
plt.title("Housing Price by ID")
plt.xlabel("ID")
plt.ylabel("sale price")
plt.show()

# %%
x_grid = np.arange(min(x), max(x), 0.1)
x_grid = x_grid.reshape((len(x_grid), 1))
plt.scatter(x, y, color = 'red')
plt.plot(x_grid, lin_reg_2.predict(poly_reg.fit_transform(x_grid)), color = 'blue')
plt.title("Housing Price by ID")
plt.xlabel("ID")
plt.ylabel("sale price")
plt.show()

# %%
y_pred = regressor.predict([[1489]])
print("Housing Price by ID : 1489 =")
print(y_pred)
# Out:
# Housing Price by ID : 1489 =
# [[175498.98429305]]

# %%
y_pred = regressor.predict([[3420]])
print("Housing Price by ID : 3420 =")
print(y_pred)
# Out:
# Housing Price by ID : 3420 =
# [[185015.81186712]]
